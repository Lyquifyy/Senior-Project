# %% [markdown]
# Import EPA fuel economy data from 2009-2025

# %%
import pandas as pd

#xlsx
data_25 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\25-testcar-2025-05.xlsx")
data_24 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\24-testcar-2025-05.xlsx")
data_23 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\23-testcar-2024-05-17_0.xlsx")
data_22 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\22-testcar-2023-06-13.xlsx")
data_21 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\21-tstcar-2022-04-15.xlsx")
data_20 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\20tstcar-2021-03-02.xlsx")
data_19 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\19tstcar-2020-10-02.xlsx")
data_18 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\18tstcar-2018-10-24.xlsx")
data_17 = pd.read_excel(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\Excel\17tstcar-2018-05-30.xlsx")

#csv
data_16 = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\16tstcar.csv")
data_15 = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\15tstcar.csv")
data_14 = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\14tstcar.csv")
data_13 = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\13tstcar.csv")
data_12 = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\12tstcar.csv")
data_11 = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\11tstcar.csv")
data_10 = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\10tstcar.csv")
data_09lr = pd.read_csv(r"C:\Users\clair\Senior-Project\EPA Data Cleaning\Raw Data\CSV\09tstcar-laterelease.csv")

# %% [markdown]
# Convert data to dataframes to begin cleaning

# %%
df_25 = pd.DataFrame(data_25)
df_24 = pd.DataFrame(data_24)
df_23 = pd.DataFrame(data_23)
df_22 = pd.DataFrame(data_22)
df_21 = pd.DataFrame(data_21)
df_20 = pd.DataFrame(data_20)
df_19 = pd.DataFrame(data_19)
df_18 = pd.DataFrame(data_18)
df_17 = pd.DataFrame(data_17)
df_16 = pd.DataFrame(data_16)
df_15 = pd.DataFrame(data_15)
df_14 = pd.DataFrame(data_14)
df_13 = pd.DataFrame(data_13)
df_12 = pd.DataFrame(data_12)
df_11 = pd.DataFrame(data_11)
df_10 = pd.DataFrame(data_10)
df_09lr = pd.DataFrame(data_09lr)

# %% [markdown]
# Append dataframes for 2017-2025 into one dataframe, and 2009-2016 into one dataframe

# %%
merged_17to25 = pd.concat([df_25,df_24,df_23,df_22,df_21,df_20,df_19,df_18,df_17], ignore_index=True)
merged_09to16 = pd.concat([df_16,df_15,df_14,df_13,df_12,df_11,df_10,df_09lr], ignore_index=True)

# %%
merged_17to25.head(2)
# Out:
#    Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# 0        2025              aston martin          ASX
# 1        2025              aston martin          ASX
#
#   Represented Test Veh Make Represented Test Veh Model Test Vehicle ID  \
# 0              Aston Martin                    DB12 V8      5723PT5601
# 1              Aston Martin                    DB12 V8      5723PT5601
#
#    Test Veh Configuration #  Test Veh Displacement (L)  \
# 0                         0                        4.0
# 1                         0                        4.0
#
#   Actual Tested Testgroup Vehicle Type  ...  Set Coef A (lbf)  \
# 0            RASXV04.0AES          Car  ...              5.67
# 1            RASXV04.0AES          Car  ...              5.67
#
#    Set Coef B (lbf/mph) Set Coef C (lbf/mph**2) Aftertreatment Device Cd  \
# 0                0.0083                  0.0221                      TWC
# 1                0.0083                  0.0221                      TWC
#
# ...

# %%
merged_17to25.tail(2)
# Out:
#        Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# 40391        2017                     Volvo          VVX
# 40392        2017                     Volvo          VVX
#
#       Represented Test Veh Make Represented Test Veh Model Test Vehicle ID  \
# 40391                     Volvo                XC90 T8 AWD          201621
# 40392                     Volvo                XC90 T8 AWD          201621
#
#        Test Veh Configuration #  Test Veh Displacement (L)  \
# 40391                         1                      1.969
# 40392                         1                      1.969
#
#       Actual Tested Testgroup Vehicle Type  ...  Set Coef A (lbf)  \
# 40391            GVVXT02.0P3T        Truck  ...              -0.6
# 40392            GVVXT02.0P3T        Truck  ...              -0.6
#
#        Set Coef B (lbf/mph) Set Coef C (lbf/mph**2) Aftertreatment Device Cd  \
# 40391                -0.186                  0.0278                      TWC
# ...

# %%
merged_09to16.head(2)
# Out:
#    Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# 0        2016              aston martin          ASX
# 1        2016              aston martin          ASX
#
#   Represented Test Veh Make Represented Test Veh Model Test Vehicle ID  \
# 0              Aston Martin                        DB9       143TT1042
# 1              Aston Martin                        DB9       143TT1042
#
#    Test Veh Configuration #  Test Veh Displacement (L)  \
# 0                         0                        5.9
# 1                         0                        5.9
#
#   Actual Tested Testgroup Vehicle Type  ...  Set Coef A (lbf)  \
# 0            DASXV05.9VH1          Car  ...              8.35
# 1            DASXV05.9VH1          Car  ...              8.35
#
#    Set Coef B (lbf/mph) Set Coef C (lbf/mph**2) Aftertreatment Device Cd  \
# 0                 0.299                  0.0192                      TWC
# 1                 0.299                  0.0192                      TWC
#
# ...

# %%
merged_09to16.tail(2)
# Out:
#        Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# 29935        2009                     Volvo          VVX
# 29936        2009                     Volvo          VVX
#
#       Represented Test Veh Make Represented Test Veh Model Test Vehicle ID  \
# 29935                     Volvo               S40 2.4i FWD          200806
# 29936                     Volvo               S40 2.4i FWD          200806
#
#        Test Veh Configuration #  Test Veh Displacement (L)  \
# 29935                         2                      2.435
# 29936                         2                      2.435
#
#       Actual Tested Testgroup Vehicle Type  ...  Set Coef A (lbf)  \
# 29935            AVVXV02.4U2N          Car  ...             13.92
# 29936            AVVXV02.4U2N          Car  ...             16.60
#
#        Set Coef B (lbf/mph) Set Coef C (lbf/mph**2) Aftertreatment Device Cd  \
# 29935                0.1811                  0.0173                      TWC
# ...

# %%
merged_17to25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40393 entries, 0 to 40392
# Data columns (total 67 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Model Year                      40393 non-null  int64
#  1   Vehicle Manufacturer Name       40393 non-null  object
#  2   Veh Mfr Code                    40393 non-null  object
#  3   Represented Test Veh Make       40393 non-null  object
#  4   Represented Test Veh Model      40393 non-null  object
#  5   Test Vehicle ID                 40393 non-null  object
#  6   Test Veh Configuration #        40393 non-null  int64
#  7   Test Veh Displacement (L)       40393 non-null  float64
#  8   Actual Tested Testgroup         40393 non-null  object
#  9   Vehicle Type                    40393 non-null  object
#  10  Rated Horsepower                40393 non-null  int64
#  11  # of Cylinders and Rotors       37617 non-null  float64
# ...

# %%
merged_09to16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29937 entries, 0 to 29936
# Data columns (total 67 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Model Year                      29937 non-null  int64
#  1   Vehicle Manufacturer Name       29937 non-null  object
#  2   Veh Mfr Code                    29937 non-null  object
#  3   Represented Test Veh Make       29937 non-null  object
#  4   Represented Test Veh Model      29937 non-null  object
#  5   Test Vehicle ID                 29937 non-null  object
#  6   Test Veh Configuration #        29937 non-null  int64
#  7   Test Veh Displacement (L)       29937 non-null  float64
#  8   Actual Tested Testgroup         29937 non-null  object
#  9   Vehicle Type                    29937 non-null  object
#  10  Rated Horsepower                29937 non-null  int64
#  11  # of Cylinders and Rotors       27535 non-null  float64
# ...

# %% [markdown]
# Filter out unnecessary columns

# %%
columns_to_keep = ['Veh Mfr Code', 'Represented Test Veh Make', 'Represented Test Veh Model',
                'Test Vehicle ID', 'Vehicle Type', 'Test Fuel Type Cd', 'Test Fuel Type Description',
                 'CO2 (g/mi)']
filtered_17to25 = merged_17to25[columns_to_keep]
filtered_09to16 = merged_09to16[columns_to_keep]

# %%
filtered_17to25.head()
# Out:
#   Veh Mfr Code Represented Test Veh Make Represented Test Veh Model  \
# 0          ASX              Aston Martin                    DB12 V8
# 1          ASX              Aston Martin                    DB12 V8
# 2          ASX              Aston Martin                    DBX 707
# 3          ASX              Aston Martin                    DBX 707
# 4          ASX              Aston Martin                   Vanquish
#
#   Test Vehicle ID Vehicle Type  Test Fuel Type Cd Test Fuel Type Description  \
# 0      5723PT5601          Car                 61       Tier 2 Cert Gasoline
# 1      5723PT5601          Car                 61       Tier 2 Cert Gasoline
# 2      8841PT8473         Both                 61       Tier 2 Cert Gasoline
# 3      8841PT8473         Both                 61       Tier 2 Cert Gasoline
# 4       370TT7334          Car                 61       Tier 2 Cert Gasoline
#
#    CO2 (g/mi)
# 0     484.329
# 1     283.235
# 2     486.750
# 3     331.480
# 4     546.351

# %%
filtered_09to16.head()
# Out:
#   Veh Mfr Code Represented Test Veh Make Represented Test Veh Model  \
# 0          ASX              Aston Martin                        DB9
# 1          ASX              Aston Martin                        DB9
# 2          ASX              Aston Martin                   Rapide S
# 3          ASX              Aston Martin                   Rapide S
# 4          ASX              Aston Martin              V12 Vantage S
#
#   Test Vehicle ID Vehicle Type  Test Fuel Type Cd Test Fuel Type Description  \
# 0       143TT1042          Car                 61       Tier 2 Cert Gasoline
# 1       143TT1042          Car                 61       Tier 2 Cert Gasoline
# 2       410TT4202          Car                 61       Tier 2 Cert Gasoline
# 3       410TT4202          Car                 61       Tier 2 Cert Gasoline
# 4       288TT2087          Car                 61       Tier 2 Cert Gasoline
#
#    CO2 (g/mi)
# 0      550.27
# 1      343.88
# 2      511.93
# 3      296.63
# 4      603.49

# %% [markdown]
# Average CO2 emissions for cars of same make and model from different years

# %%
avg_17to25 = filtered_17to25.groupby(['Represented Test Veh Make', 'Represented Test Veh Model']).agg({
    'CO2 (g/mi)': 'mean',
    'Veh Mfr Code': 'first', 
    'Vehicle Type': 'first',
    'Test Vehicle ID': 'first'
}).reset_index()

avg_09to16 = filtered_09to16.groupby(['Represented Test Veh Make', 'Represented Test Veh Model']).agg({
    'CO2 (g/mi)': 'mean',
    'Veh Mfr Code': 'first',  
    'Vehicle Type': 'first',
    'Test Vehicle ID': 'first'
}).reset_index()

# %%
avg_17to25.head(30)
# Out:
#    Represented Test Veh Make  Represented Test Veh Model  CO2 (g/mi)  \
# 0                       2022           Lucid Air Dream P         NaN
# 1                       2022           Lucid Air Dream R         NaN
# 2                       2022     Lucid Air Grand Touring         NaN
# 3                       2023           Lucid Air Touring         NaN
# 4                       2024   Air Pure RWD w/19" wheels         NaN
# 5                       2024   Air Pure RWD w/20" wheels         NaN
# 6                       2024            Air Sapphire AWD         NaN
# 7                       2024  Lucid Air Grand Touring XR         NaN
# 8                       2024       Lucid Air Touring AWD         NaN
# 9                       2025   Air Pure RWD w/19" wheels         NaN
# 10                      2025   Air Pure RWD w/20" wheels         NaN
# 11                      2025       Lucid Gravity GT (2R)         NaN
# 12                      2025       Lucid Gravity GT (3R)         NaN
# ...

# %%
avg_17to25.tail()
# Out:
#      Represented Test Veh Make           Represented Test Veh Model  \
# 2312                     Volvo                          XC90 T5 FWD
# 2313                     Volvo                          XC90 T6 AWD
# 2314                     Volvo                          XC90 T8 AWD
# 2315                     Volvo                 XC90 T8 AWD Recharge
# 2316                     Volvo  XC90 T8 AWD Recharge Extended Range
#
#       CO2 (g/mi) Veh Mfr Code Vehicle Type Test Vehicle ID
# 2312  274.153846          VVX         Both          202006
# 2313  312.519525          VVX         Both          202107
# 2314  264.231594          VVX         Both          202001
# 2315  245.000000          VVX         Both          202308
# 2316  247.928139          VVX         Both          202211

# %%
avg_09to16.head()
# Out:
#   Represented Test Veh Make Represented Test Veh Model  CO2 (g/mi)  \
# 0                     ACURA                        ILX  290.192174
# 1                     ACURA                 ILX HYBRID  184.771111
# 2                     ACURA                    MDX 2WD  288.207500
# 3                     ACURA                    MDX 4WD  341.777223
# 4                     ACURA                    RDX 2WD  287.412500
#
#   Veh Mfr Code Vehicle Type Test Vehicle ID
# 0          HNX          Car          EG4H1D
# 1          HNX          Car          ED9C2C
# 2          HNX          Car          EGJ62A
# 3          HNX          Car          EGJ61A
# 4          HNX        Truck          EGME2A

# %%
avg_09to16.tail()
# Out:
#      Represented Test Veh Make Represented Test Veh Model  CO2 (g/mi)  \
# 1542                     Volvo                XC90 T5 FWD  302.666667
# 1543                     Volvo                XC90 T6 AWD  323.750000
# 1544                     Volvo                XC90 T8 AWD  297.784250
# 1545                     Volvo                XC90 V8 AWD  483.571429
# 1546             W204E63-Z1011                   C 63 AMG  439.750000
#
#      Veh Mfr Code Vehicle Type Test Vehicle ID
# 1542          VVX        Truck          201612
# 1543          VVX        Truck          201601
# 1544          VVX        Truck          201615
# 1545          VVX        Truck          201101
# 1546          MBX          Car   W204E63-Z1011

# %% [markdown]
# Drop rows that do not report any CO2 emissions

# %%
clean_17to25 = avg_17to25.dropna(subset=['CO2 (g/mi)'])
clean_09to16 = avg_09to16.dropna(subset=['CO2 (g/mi)'])

# %%
clean_17to25.head(20)
# Out:
#    Represented Test Veh Make Represented Test Veh Model  CO2 (g/mi)  \
# 13                     ACURA                    ADX AWD  233.475000
# 14                     ACURA                    ADX FWD  221.080000
# 15                     ACURA                        ILX  227.985000
# 16                     ACURA                    INTEGRA  239.378571
# 17                     ACURA             INTEGRA A-SPEC  206.239250
# 18                     ACURA                    MDX AWD  313.575000
# 19                     ACURA             MDX AWD A-spec  310.665000
# 20                     ACURA             MDX AWD Type-S  372.876667
# 21                     ACURA                    MDX FWD  298.330000
# 22                     ACURA                        NSX  299.235000
# 23                     ACURA                    RDX 2WD  286.670000
# 24                     ACURA                    RDX 4WD  299.450000
# 25                     ACURA                    RDX AWD  276.580000
# ...

# %%
clean_09to16.head(30)
# Out:
#    Represented Test Veh Make Represented Test Veh Model  CO2 (g/mi)  \
# 0                      ACURA                        ILX  290.192174
# 1                      ACURA                 ILX HYBRID  184.771111
# 2                      ACURA                    MDX 2WD  288.207500
# 3                      ACURA                    MDX 4WD  341.777223
# 4                      ACURA                    RDX 2WD  287.412500
# 5                      ACURA                    RDX 4WD  298.827500
# 6                      ACURA              RDX BASE/TECH  328.335000
# 7                      ACURA                         RL  365.075000
# 8                      ACURA                 RLX HYBRID  217.686019
# 9                      ACURA                     TL 2WD  298.108000
# 10                     ACURA                     TL 4WD  328.369000
# 11                     ACURA                        TLX  246.027953
# 12                     ACURA                        TSX  272.908750
# ...

# %% [markdown]
# Export clean data to csv

# %%
clean_09to16.to_csv('09to16_models.csv')
clean_17to25.to_csv('17to25_models.csv')

# %% [markdown]
# Vehicle Type only CO2

# %%
type_only_17to25 = filtered_17to25.groupby(['Vehicle Type']).agg({
    'CO2 (g/mi)': 'mean',
}).reset_index()

type_only_09to16 = filtered_09to16.groupby(['Vehicle Type']).agg({
    'CO2 (g/mi)': 'mean',
}).reset_index()
type_only_09to16.head()
# Out:
#   Vehicle Type  CO2 (g/mi)
# 0         Both  306.266060
# 1          Car  305.495892
# 2        Truck  374.408104

# %%
type_only_17to25.head()
# Out:
#   Vehicle Type  CO2 (g/mi)
# 0         Both  288.690007
# 1          Car  293.973187
# 2        Truck  335.079088

# %% [markdown]
# Export vehicle Type only to CSV

# %%
type_only_17to25.to_csv('17to25_type_only.csv')
type_only_09to16.to_csv('09to16_type_only.csv')

# %% [markdown]
# type only CO2 all years

# %%
type_only_allyears = pd.merge(type_only_09to16, type_only_17to25, 
                 on='Vehicle Type',
                 suffixes=('_09to16', '_17to25'))


type_only_allyears['Average_CO2'] = (type_only_allyears['CO2 (g/mi)_09to16'] + type_only_allyears['CO2 (g/mi)_17to25']) / 2


type_only_allyears.head()
# Out:
#   Vehicle Type  CO2 (g/mi)_09to16  CO2 (g/mi)_17to25  Average_CO2
# 0         Both         306.266060         288.690007   297.478034
# 1          Car         305.495892         293.973187   299.734540
# 2        Truck         374.408104         335.079088   354.743596

# %%
columns_to_keep2 = ['Vehicle Type','Average_CO2']
type_only_allyears = type_only_allyears[columns_to_keep2]
type_only_allyears.head()
# Out:
#   Vehicle Type  Average_CO2
# 0         Both   297.478034
# 1          Car   299.734540
# 2        Truck   354.743596

# %%
type_only_allyears.to_csv('type_only_allyears.csv')
